# %%
import pickle

with open('product_titles.pkl', 'rb') as f:
    product_titles = pickle.load(f)

print("Total titles:", len(product_titles))

# print a few examples
for pid, title in list(product_titles.items())[:10]:
    print(pid, "->", title)
# Out:
# Total titles: 27606
# 0006641040 ->  Maurice Sendak's 1962 children's book is about a whirlwind chicken soup year . In this book we are led
# B00002N8SM ->  Ineffective and worthless . Don't waste your money on this product . Indoor trap has caught zero flies yet
# B00004CXX9 ->  Keaton is hilarious as the wacky beetlejuice . I think this is one of the best movies ever
# B00004RAMS ->  Moles are not like mice or rats, they breed slowly and live alone . They reproduce once per year and
# B00004RAMV ->  Large, therefore keeps its content for a while and easy to fill/use/reuse . You'll get
# B00004RAMX ->  The design of this trap seems to count on the animal pushing dirt in front of him and the dirt is what
# B00004RAMY ->  The trap itself seems to be great. The instructions are not very clear but you can find videos on youtube for
# B00004RBDU ->  Both my cat and dogs have fleas and scratching like crazy yet this product did not catch ONE flea!!!
# ...

# %%
pid = "0006641040"
print(product_titles.get(pid, "Not found"))
# Out:
#  Maurice Sendak's 1962 children's book is about a whirlwind chicken soup year . In this book we are led
